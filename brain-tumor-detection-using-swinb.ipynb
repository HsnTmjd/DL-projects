# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/brain-mri-images-for-brain-tumor-detection

# %%
pip install torch torchvision opencv-python matplotlib tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.0 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 6.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 45.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
# Generate data paths with labels
data_dir = '/kaggle/input/brain-mri-images-for-brain-tumor-detection'
filepaths = []
labels = []

folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        
        filepaths.append(fpath)
        labels.append(fold)
        
# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis= 1)

# %%
df
# Out:
#                                              filepaths               labels
# 0    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 1    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 2    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 3    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 4    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# ..                                                 ...                  ...
# 250  /kaggle/input/brain-mri-images-for-brain-tumor...                  yes
# 251  /kaggle/input/brain-mri-images-for-brain-tumor...                  yes
# 252  /kaggle/input/brain-mri-images-for-brain-tumor...                  yes
# 253  /kaggle/input/brain-mri-images-for-brain-tumor...  brain_tumor_dataset
# 254  /kaggle/input/brain-mri-images-for-brain-tumor...  brain_tumor_dataset
#
# [255 rows x 2 columns]

# %%
import os
import shutil
import random
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

# Define paths
data_dir = '/kaggle/input/brain-mri-images-for-brain-tumor-detection'
filepaths = []
labels = []

# List directories (yes, no)
folds = os.listdir(data_dir)
for fold in folds:
    foldpath = os.path.join(data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries, Lseries], axis= 1)

# Split data into training and testing sets using train_test_split
strat = df['labels']  # Stratify by labels to maintain class distribution
train_df, test_df = train_test_split(df, train_size=0.8, shuffle=True, random_state=123, stratify=strat)

# Define directories for train and test datasets
base_dir = "/kaggle/working/split_dataset"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")

# Ensure the main directories exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Create subfolders for yes and no inside train and test directories
os.makedirs(os.path.join(train_dir, "yes"), exist_ok=True)
os.makedirs(os.path.join(train_dir, "no"), exist_ok=True)

os.makedirs(os.path.join(test_dir, "yes"), exist_ok=True)
os.makedirs(os.path.join(test_dir, "no"), exist_ok=True)

# Function to apply thermal effect to the image
def apply_thermal_effect(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Failed to load image {image_path}")  # Debug message for invalid paths
        return None  # Return None if image couldn't be loaded
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

    # Step 1: Enhance contrast using CLAHE
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    enhanced_gray = clahe.apply(gray)

    # Step 2: Apply Thermal (Heatmap) Effect
    thermal_img = cv2.applyColorMap(enhanced_gray, cv2.COLORMAP_JET)  # Thermal-like effect

    return thermal_img

# Function to copy images from the source folder to the destination folder
def copy_images(image_files, src_folder, dest_folder):
    for image_file in image_files:
        src_path = os.path.join(src_folder, image_file)
        dest_path = os.path.join(dest_folder, image_file)
        shutil.copy(src_path, dest_path)  # Use copy instead of move
        print(f"Copied: {image_file} from {src_folder} to {dest_folder}")  # Debug message

# Now apply thermal effects and copy images for train and test datasets
# Process images for the training set (80%) from train_df to the appropriate train folder (yes or no)
for _, row in train_df.iterrows():
    label = row['labels']
    image_file = os.path.basename(row['filepaths'])
    
    # Copy the original image to the appropriate folder
    if label == 'yes':
        copy_images([image_file], os.path.dirname(row['filepaths']), os.path.join(train_dir, "yes"))
    elif label == 'no':
        copy_images([image_file], os.path.dirname(row['filepaths']), os.path.join(train_dir, "no"))
    
    # Apply thermal effect and save the thermal image in the same folder
    thermal_image = apply_thermal_effect(row['filepaths'])
    if thermal_image is not None:  # Proceed only if the thermal image was successfully created
        thermal_save_path = os.path.join(train_dir, label, f"thermal_{image_file}")
        cv2.imwrite(thermal_save_path, thermal_image)

# Process images for the test set (20%) from test_df to the appropriate test folder (yes or no)
for _, row in test_df.iterrows():
    label = row['labels']
    image_file = os.path.basename(row['filepaths'])
    
    # Copy the original image to the appropriate folder
    if label == 'yes':
        copy_images([image_file], os.path.dirname(row['filepaths']), os.path.join(test_dir, "yes"))
    elif label == 'no':
        copy_images([image_file], os.path.dirname(row['filepaths']), os.path.join(test_dir, "no"))
    
    # Apply thermal effect and save the thermal image in the same folder
    thermal_image = apply_thermal_effect(row['filepaths'])
    if thermal_image is not None:  # Proceed only if the thermal image was successfully created
        thermal_save_path = os.path.join(test_dir, label, f"thermal_{image_file}")
        cv2.imwrite(thermal_save_path, thermal_image)

print(f"Images and thermal effects successfully copied and processed in {train_dir} and {test_dir}.")
# Out:
# Copied: 6 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y75.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: No17.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N17.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: No11.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y47.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y69.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y158.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 92.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N15.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 41 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y153.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 90.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: No20.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 50 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y242.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: No12.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y92.png from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y32.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y161.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 46 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 28 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y187.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 4 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y42.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y248.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 9.png from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N2.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 27 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 12 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 25 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 7 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y28.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y53.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y77.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y9.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 43 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y182.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 100.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y245.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 21 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y111.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: N20.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: No16.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y98.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 10 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 11 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y60.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y4.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y148.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y255.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 15 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 32 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y56.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 19 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N26.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y2.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y185.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y186.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y14.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y164.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y155.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 26 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y23.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y250.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 31 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y253.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 89.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: No18.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y156.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: No21.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y106.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y243.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 99.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y195.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: No13.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y59.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 49 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y36.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 14 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N5.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y90.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y35.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y108.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y100.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: No19.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: no 1.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: no 96.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y113.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y58.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y107.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y85.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 45 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 22 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y37.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 44no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y38.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 923.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y258.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y13.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 91.jpeg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y30.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y183.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y70.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y92.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y168.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 95.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y67.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y16.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y33.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y3.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y44.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y86.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y146.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y51.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y40.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 3 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y11.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: N22.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y159.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y12.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y101.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y109.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y31.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Error: Failed to load image /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset/yes
# Copied: 30 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y254.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 17 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y55.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y193.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y114.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y54.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: No15.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y17.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y27.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y81.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y65.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 9 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y184.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 29 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y25.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y247.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y19.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y82.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: N3.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y41.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 34 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y165.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 1 no.jpeg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y116.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y246.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y79.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 94.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N6.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y39.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y181.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y24.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y166.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y157.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y249.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 20 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: N16.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y50.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y169.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y18.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y74.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y66.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 38 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 24 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: no 5.jpeg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 33 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y102.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y22.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y112.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 35 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: no 98.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y73.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y29.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y188.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 13 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y147.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 6.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 36 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: 18 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y117.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y259.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y162.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Error: Failed to load image /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset/no
# Copied: Y120.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 5 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y180.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y192.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y1.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y8.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y163.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y194.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y49.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y76.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: 42 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y96.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: no 10.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/train/no
# Copied: Y10.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y252.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/train/yes
# Copied: Y62.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y95.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y6.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y89.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y71.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y91.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y26.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 37 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y21.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y99.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y154.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y256.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 48 no.jpeg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y46.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: no 3.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y52.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y160.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y78.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 39 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: No22.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y97.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: no 2.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y167.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 40 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y15.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y115.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: N11.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: N21.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y170.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: no 4.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: no 7.jpeg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y34.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y244.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 8 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y61.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 23 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: no 8.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: N19.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y103.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: No14.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y20.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y104.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: no 97.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y7.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y251.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y105.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: Y45.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: N1.JPG from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: 2 no.jpeg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Copied: Y257.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes to /kaggle/working/split_dataset/test/yes
# Copied: 47 no.jpg from /kaggle/input/brain-mri-images-for-brain-tumor-detection/no to /kaggle/working/split_dataset/test/no
# Images and thermal effects successfully copied and processed in /kaggle/working/split_dataset/train and /kaggle/working/split_dataset/test.

# %%
import os

# Define paths for train and test datasets
base_dir = "/kaggle/working/split_dataset"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")

# Count the number of images in each folder (yes/no) in the train and test datasets
train_yes_count = len(os.listdir(os.path.join(train_dir, "yes")))
train_no_count = len(os.listdir(os.path.join(train_dir, "no")))

test_yes_count = len(os.listdir(os.path.join(test_dir, "yes")))
test_no_count = len(os.listdir(os.path.join(test_dir, "no")))

# Display the counts
train_yes_count, train_no_count, test_yes_count, test_no_count
# Out:
# (248, 156, 62, 40)

# %%
import os
import shutil
import cv2
import numpy as np

# Define paths for train and test datasets
base_dir = "/kaggle/working/split_dataset"
train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
train_thermal_dir = os.path.join(base_dir, "train_thermal")
test_thermal_dir = os.path.join(base_dir, "test_thermal")

# Ensure the main directories exist
os.makedirs(train_thermal_dir, exist_ok=True)
os.makedirs(test_thermal_dir, exist_ok=True)

# Create subfolders for yes and no inside train_thermal and test_thermal directories
os.makedirs(os.path.join(train_thermal_dir, "yes"), exist_ok=True)
os.makedirs(os.path.join(train_thermal_dir, "no"), exist_ok=True)

os.makedirs(os.path.join(test_thermal_dir, "yes"), exist_ok=True)
os.makedirs(os.path.join(test_thermal_dir, "no"), exist_ok=True)

# Function to apply thermal effect to the image
def apply_thermal_effect(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert to grayscale

    # Step 1: Enhance contrast using CLAHE
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    enhanced_gray = clahe.apply(gray)

    # Step 2: Apply Thermal (Heatmap) Effect
    thermal_img = cv2.applyColorMap(enhanced_gray, cv2.COLORMAP_JET)  # Thermal-like effect

    return thermal_img

# Function to process the images and save them in the new folder structure
def process_and_save_images(df, destination_dir):
    for _, row in df.iterrows():
        label = row['labels']
        image_file = os.path.basename(row['filepaths'])
        image_name, ext = os.path.splitext(image_file)

        # Ensure we are working with files, not directories
        if os.path.isdir(row['filepaths']):
            print(f"Skipping directory: {row['filepaths']}")
            continue

        # Create a new folder for this image inside train/test directories (named after the image)
        image_folder = os.path.join(destination_dir, label, image_name)
        os.makedirs(image_folder, exist_ok=True)

        # Copy the original image to this new folder
        original_image_path = row['filepaths']
        shutil.copy(original_image_path, os.path.join(image_folder, image_file))

        # Apply thermal effect to the image
        thermal_image = apply_thermal_effect(os.path.join(image_folder, image_file))
        if thermal_image is not None:
            # Save the thermal image with the prefix 'thermal_' in the same folder
            thermal_save_path = os.path.join(image_folder, f"thermal_{image_file}")
            cv2.imwrite(thermal_save_path, thermal_image)
            print(f"Processed and saved: {image_file} and its thermal version.")

# Process and save images for the training set
process_and_save_images(train_df, train_thermal_dir)

# Process and save images for the test set
process_and_save_images(test_df, test_thermal_dir)

print("Images and thermal effects successfully processed and saved in the respective directories.")
# Out:
# Processed and saved: 6 no.jpg and its thermal version.
# Processed and saved: Y75.JPG and its thermal version.
# Processed and saved: No17.jpg and its thermal version.
# Processed and saved: N17.jpg and its thermal version.
# Processed and saved: No11.jpg and its thermal version.
# Processed and saved: Y47.JPG and its thermal version.
# Processed and saved: Y69.jpg and its thermal version.
# Processed and saved: Y158.JPG and its thermal version.
# Processed and saved: no 92.jpg and its thermal version.
# Processed and saved: N15.jpg and its thermal version.
# Processed and saved: 41 no.jpg and its thermal version.
# Processed and saved: Y153.jpg and its thermal version.
# Processed and saved: no 90.jpg and its thermal version.
# Processed and saved: No20.jpg and its thermal version.
# Processed and saved: 50 no.jpg and its thermal version.
# Processed and saved: Y242.JPG and its thermal version.
# Processed and saved: No12.jpg and its thermal version.
# Processed and saved: Y92.png and its thermal version.
# Processed and saved: no.jpg and its thermal version.
# Processed and saved: Y32.jpg and its thermal version.
# Processed and saved: Y161.JPG and its thermal version.
# Processed and saved: 46 no.jpg and its thermal version.
# Processed and saved: 28 no.jpg and its thermal version.
# Processed and saved: Y187.jpg and its thermal version.
# Processed and saved: 4 no.jpg and its thermal version.
# Processed and saved: Y42.jpg and its thermal version.
# Processed and saved: Y248.JPG and its thermal version.
# Processed and saved: no 9.png and its thermal version.
# Processed and saved: N2.JPG and its thermal version.
# Processed and saved: 27 no.jpg and its thermal version.
# Processed and saved: 12 no.jpg and its thermal version.
# Processed and saved: 25 no.jpg and its thermal version.
# Processed and saved: 7 no.jpg and its thermal version.
# Processed and saved: Y28.jpg and its thermal version.
# Processed and saved: Y53.jpg and its thermal version.
# Processed and saved: Y77.jpg and its thermal version.
# Processed and saved: Y9.jpg and its thermal version.
# Processed and saved: 43 no.jpg and its thermal version.
# Processed and saved: Y182.JPG and its thermal version.
# Processed and saved: no 100.jpg and its thermal version.
# Processed and saved: Y245.jpg and its thermal version.
# Processed and saved: 21 no.jpg and its thermal version.
# Processed and saved: Y111.JPG and its thermal version.
# Processed and saved: N20.JPG and its thermal version.
# Processed and saved: No16.jpg and its thermal version.
# Processed and saved: Y98.JPG and its thermal version.
# Processed and saved: 10 no.jpg and its thermal version.
# Processed and saved: 11 no.jpg and its thermal version.
# Processed and saved: Y60.jpg and its thermal version.
# Processed and saved: Y4.jpg and its thermal version.
# Processed and saved: Y148.JPG and its thermal version.
# Processed and saved: Y255.JPG and its thermal version.
# Processed and saved: 15 no.jpg and its thermal version.
# Processed and saved: 32 no.jpg and its thermal version.
# Processed and saved: Y56.jpg and its thermal version.
# Processed and saved: 19 no.jpg and its thermal version.
# Processed and saved: N26.JPG and its thermal version.
# Processed and saved: Y2.jpg and its thermal version.
# Processed and saved: Y185.jpg and its thermal version.
# Processed and saved: Y186.jpg and its thermal version.
# Processed and saved: Y14.jpg and its thermal version.
# Processed and saved: Y164.JPG and its thermal version.
# Processed and saved: Y155.JPG and its thermal version.
# Processed and saved: 26 no.jpg and its thermal version.
# Processed and saved: Y23.JPG and its thermal version.
# Processed and saved: Y250.jpg and its thermal version.
# Processed and saved: 31 no.jpg and its thermal version.
# Processed and saved: Y253.JPG and its thermal version.
# Processed and saved: no 89.jpg and its thermal version.
# Processed and saved: No18.jpg and its thermal version.
# Processed and saved: Y156.JPG and its thermal version.
# Processed and saved: No21.jpg and its thermal version.
# Processed and saved: Y106.jpg and its thermal version.
# Processed and saved: Y243.JPG and its thermal version.
# Processed and saved: no 99.jpg and its thermal version.
# Processed and saved: Y195.JPG and its thermal version.
# Processed and saved: No13.jpg and its thermal version.
# Processed and saved: Y59.JPG and its thermal version.
# Processed and saved: 49 no.jpg and its thermal version.
# Processed and saved: Y36.JPG and its thermal version.
# Processed and saved: 14 no.jpg and its thermal version.
# Processed and saved: N5.jpg and its thermal version.
# Processed and saved: Y90.jpg and its thermal version.
# Processed and saved: Y35.jpg and its thermal version.
# Processed and saved: Y108.jpg and its thermal version.
# Processed and saved: Y100.JPG and its thermal version.
# Processed and saved: No19.jpg and its thermal version.
# Processed and saved: no 1.jpg and its thermal version.
# Processed and saved: no 96.jpg and its thermal version.
# Processed and saved: Y113.JPG and its thermal version.
# Processed and saved: Y58.JPG and its thermal version.
# Processed and saved: Y107.jpg and its thermal version.
# Processed and saved: Y85.JPG and its thermal version.
# Processed and saved: 45 no.jpg and its thermal version.
# Processed and saved: 22 no.jpg and its thermal version.
# Processed and saved: Y37.jpg and its thermal version.
# Processed and saved: 44no.jpg and its thermal version.
# Processed and saved: Y38.jpg and its thermal version.
# Processed and saved: no 923.jpg and its thermal version.
# Processed and saved: Y258.JPG and its thermal version.
# Processed and saved: Y13.jpg and its thermal version.
# Processed and saved: no 91.jpeg and its thermal version.
# Processed and saved: Y30.jpg and its thermal version.
# Processed and saved: Y183.jpg and its thermal version.
# Processed and saved: Y70.jpg and its thermal version.
# Processed and saved: Y92.jpg and its thermal version.
# Processed and saved: Y168.jpg and its thermal version.
# Processed and saved: no 95.jpg and its thermal version.
# Processed and saved: Y67.JPG and its thermal version.
# Processed and saved: Y16.JPG and its thermal version.
# Processed and saved: Y33.jpg and its thermal version.
# Processed and saved: Y3.jpg and its thermal version.
# Processed and saved: Y44.JPG and its thermal version.
# Processed and saved: Y86.JPG and its thermal version.
# Processed and saved: Y146.JPG and its thermal version.
# Processed and saved: Y51.jpg and its thermal version.
# Processed and saved: Y40.JPG and its thermal version.
# Processed and saved: 3 no.jpg and its thermal version.
# Processed and saved: Y11.jpg and its thermal version.
# Processed and saved: N22.JPG and its thermal version.
# Processed and saved: Y159.JPG and its thermal version.
# Processed and saved: Y12.jpg and its thermal version.
# Processed and saved: Y101.jpg and its thermal version.
# Processed and saved: Y109.JPG and its thermal version.
# Processed and saved: Y31.jpg and its thermal version.
# Skipping directory: /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset/yes
# Processed and saved: 30 no.jpg and its thermal version.
# Processed and saved: Y254.jpg and its thermal version.
# Processed and saved: 17 no.jpg and its thermal version.
# Processed and saved: Y55.jpg and its thermal version.
# Processed and saved: Y193.JPG and its thermal version.
# Processed and saved: Y114.JPG and its thermal version.
# Processed and saved: Y54.jpg and its thermal version.
# Processed and saved: No15.jpg and its thermal version.
# Processed and saved: Y17.jpg and its thermal version.
# Processed and saved: Y27.jpg and its thermal version.
# Processed and saved: Y81.jpg and its thermal version.
# Processed and saved: Y65.JPG and its thermal version.
# Processed and saved: 9 no.jpg and its thermal version.
# Processed and saved: Y184.JPG and its thermal version.
# Processed and saved: 29 no.jpg and its thermal version.
# Processed and saved: Y25.jpg and its thermal version.
# Processed and saved: Y247.JPG and its thermal version.
# Processed and saved: Y19.JPG and its thermal version.
# Processed and saved: Y82.jpg and its thermal version.
# Processed and saved: N3.jpg and its thermal version.
# Processed and saved: Y41.jpg and its thermal version.
# Processed and saved: 34 no.jpg and its thermal version.
# Processed and saved: Y165.JPG and its thermal version.
# Processed and saved: 1 no.jpeg and its thermal version.
# Processed and saved: Y116.JPG and its thermal version.
# Processed and saved: Y246.JPG and its thermal version.
# Processed and saved: Y79.jpg and its thermal version.
# Processed and saved: no 94.jpg and its thermal version.
# Processed and saved: N6.jpg and its thermal version.
# Processed and saved: Y39.jpg and its thermal version.
# Processed and saved: Y181.jpg and its thermal version.
# Processed and saved: Y24.jpg and its thermal version.
# Processed and saved: Y166.JPG and its thermal version.
# Processed and saved: Y157.JPG and its thermal version.
# Processed and saved: Y249.JPG and its thermal version.
# Processed and saved: 20 no.jpg and its thermal version.
# Processed and saved: N16.jpg and its thermal version.
# Processed and saved: Y50.JPG and its thermal version.
# Processed and saved: Y169.jpg and its thermal version.
# Processed and saved: Y18.JPG and its thermal version.
# Processed and saved: Y74.jpg and its thermal version.
# Processed and saved: Y66.JPG and its thermal version.
# Processed and saved: 38 no.jpg and its thermal version.
# Processed and saved: 24 no.jpg and its thermal version.
# Processed and saved: no 5.jpeg and its thermal version.
# Processed and saved: 33 no.jpg and its thermal version.
# Processed and saved: Y102.jpg and its thermal version.
# Processed and saved: Y22.jpg and its thermal version.
# Processed and saved: Y112.JPG and its thermal version.
# Processed and saved: 35 no.jpg and its thermal version.
# Processed and saved: no 98.jpg and its thermal version.
# Processed and saved: Y73.jpg and its thermal version.
# Processed and saved: Y29.jpg and its thermal version.
# Processed and saved: Y188.jpg and its thermal version.
# Processed and saved: 13 no.jpg and its thermal version.
# Processed and saved: Y147.JPG and its thermal version.
# Processed and saved: no 6.jpg and its thermal version.
# Processed and saved: 36 no.jpg and its thermal version.
# Processed and saved: 18 no.jpg and its thermal version.
# Processed and saved: Y117.JPG and its thermal version.
# Processed and saved: Y259.JPG and its thermal version.
# Processed and saved: Y162.jpg and its thermal version.
# Skipping directory: /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset/no
# Processed and saved: Y120.JPG and its thermal version.
# Processed and saved: 5 no.jpg and its thermal version.
# Processed and saved: Y180.jpg and its thermal version.
# Processed and saved: Y192.JPG and its thermal version.
# Processed and saved: Y1.jpg and its thermal version.
# Processed and saved: Y8.jpg and its thermal version.
# Processed and saved: Y163.JPG and its thermal version.
# Processed and saved: Y194.jpg and its thermal version.
# Processed and saved: Y49.JPG and its thermal version.
# Processed and saved: Y76.jpg and its thermal version.
# Processed and saved: 42 no.jpg and its thermal version.
# Processed and saved: Y96.jpg and its thermal version.
# Processed and saved: no 10.jpg and its thermal version.
# Processed and saved: Y10.jpg and its thermal version.
# Processed and saved: Y252.jpg and its thermal version.
# Processed and saved: Y62.jpg and its thermal version.
# Processed and saved: Y95.jpg and its thermal version.
# Processed and saved: Y6.jpg and its thermal version.
# Processed and saved: Y89.JPG and its thermal version.
# Processed and saved: Y71.JPG and its thermal version.
# Processed and saved: Y91.jpg and its thermal version.
# Processed and saved: Y26.jpg and its thermal version.
# Processed and saved: 37 no.jpg and its thermal version.
# Processed and saved: Y21.jpg and its thermal version.
# Processed and saved: Y99.JPG and its thermal version.
# Processed and saved: Y154.jpg and its thermal version.
# Processed and saved: Y256.JPG and its thermal version.
# Processed and saved: 48 no.jpeg and its thermal version.
# Processed and saved: Y46.jpg and its thermal version.
# Processed and saved: no 3.jpg and its thermal version.
# Processed and saved: Y52.jpg and its thermal version.
# Processed and saved: Y160.JPG and its thermal version.
# Processed and saved: Y78.jpg and its thermal version.
# Processed and saved: 39 no.jpg and its thermal version.
# Processed and saved: No22.jpg and its thermal version.
# Processed and saved: Y97.JPG and its thermal version.
# Processed and saved: no 2.jpg and its thermal version.
# Processed and saved: Y167.JPG and its thermal version.
# Processed and saved: 40 no.jpg and its thermal version.
# Processed and saved: Y15.jpg and its thermal version.
# Processed and saved: Y115.JPG and its thermal version.
# Processed and saved: N11.jpg and its thermal version.
# Processed and saved: N21.jpg and its thermal version.
# Processed and saved: Y170.JPG and its thermal version.
# Processed and saved: no 4.jpg and its thermal version.
# Processed and saved: no 7.jpeg and its thermal version.
# Processed and saved: Y34.jpg and its thermal version.
# Processed and saved: Y244.JPG and its thermal version.
# Processed and saved: 8 no.jpg and its thermal version.
# Processed and saved: Y61.jpg and its thermal version.
# Processed and saved: 23 no.jpg and its thermal version.
# Processed and saved: no 8.jpg and its thermal version.
# Processed and saved: N19.JPG and its thermal version.
# Processed and saved: Y103.jpg and its thermal version.
# Processed and saved: No14.jpg and its thermal version.
# Processed and saved: Y20.jpg and its thermal version.
# Processed and saved: Y104.jpg and its thermal version.
# Processed and saved: no 97.jpg and its thermal version.
# Processed and saved: Y7.jpg and its thermal version.
# Processed and saved: Y251.JPG and its thermal version.
# Processed and saved: Y105.jpg and its thermal version.
# Processed and saved: Y45.JPG and its thermal version.
# Processed and saved: N1.JPG and its thermal version.
# Processed and saved: 2 no.jpeg and its thermal version.
# Processed and saved: Y257.jpg and its thermal version.
# Processed and saved: 47 no.jpg and its thermal version.
# Images and thermal effects successfully processed and saved in the respective directories.

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

# Path to the 'yes' and 'no' folders
train_thermal_dir_yes = "/kaggle/working/split_dataset/train_thermal/yes"  # 'yes' folder (with tumor)
train_thermal_dir_no = "/kaggle/working/split_dataset/train_thermal/no"    # 'no' folder (without tumor)

# Function to display a random image from a random subfolder
def display_random_image_from_subfolder(folder_path, label):
    # Get all subfolders (e.g., Y1, Y2, etc.)
    subfolders = [folder for folder in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, folder))]
    
    # Check if there are any subfolders
    if not subfolders:
        print(f"No subfolders found in {folder_path}. Skipping this folder.")
        return
    
    # Select a random subfolder
    selected_folder = random.choice(subfolders)
    
    # Construct the file paths for real and thermal images inside the selected subfolder
    real_image_path = os.path.join(folder_path, selected_folder, f"{selected_folder}.jpg")
    thermal_image_path = os.path.join(folder_path, selected_folder, f"thermal_{selected_folder}.jpg")
    
    # Check if both real and thermal images exist
    if os.path.exists(real_image_path) and os.path.exists(thermal_image_path):
        # Open and display the images
        real_image = Image.open(real_image_path)
        thermal_image = Image.open(thermal_image_path)
        
        # Plot the real and thermal images side by side
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
        axes[0].imshow(real_image)
        axes[0].set_title(f"Real Image - {label}")
        axes[0].axis('off')
        
        axes[1].imshow(thermal_image)
        axes[1].set_title(f"Thermal Image - {label}")
        axes[1].axis('off')
        
        plt.show()
    else:
        print(f"Missing image(s) for folder {selected_folder} in class {label}. Skipping this folder.")

# Display random image from 'yes' (with tumor) class
print("Displaying random image from 'yes' class (with tumor):")
display_random_image_from_subfolder(train_thermal_dir_yes, "Tumor (Yes)")

# Display random image from 'no' (without tumor) class
print("Displaying random image from 'no' class (without tumor):")
display_random_image_from_subfolder(train_thermal_dir_no, "No Tumor (No)")
# Out:
# Displaying random image from 'yes' class (with tumor):
# Displaying random image from 'no' class (without tumor):

# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch
import torch.nn as nn
import torch.optim as optim
import timm
from torch.cuda.amp import autocast, GradScaler

class ThermalImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.classes = ['yes', 'no']  # Assuming only 'yes' and 'no' classes
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}

        # Load image paths and labels for both real and thermal images
        for label in self.classes:
            class_dir = os.path.join(root_dir, label)
            print(f"Processing class: {label}")
            if os.path.isdir(class_dir):
                for img_folder in os.listdir(class_dir):
                    if img_folder.startswith('.'):
                        continue

                    image_folder_path = os.path.join(class_dir, img_folder)

                    # Skip if it's not a directory
                    if not os.path.isdir(image_folder_path):
                        continue

                    real_image_name = f"{img_folder}.jpg"
                    thermal_image_name = f"thermal_{img_folder}.jpg"

                    real_image_path = os.path.join(image_folder_path, real_image_name)
                    thermal_image_path = os.path.join(image_folder_path, thermal_image_name)

                    # Check if both images exist
                    if os.path.exists(real_image_path) and os.path.exists(thermal_image_path):
                        self.image_paths.append(real_image_path)
                        self.image_paths.append(thermal_image_path)
                        self.labels.append(self.class_to_idx[label])
                        self.labels.append(self.class_to_idx[label])
  #                  else:
#                        print(f"Missing image(s) for folder {img_folder} in class {label}")
 #           else:
#                print(f"Class directory {class_dir} does not exist or is not a directory.")

        print(f"Total images found: {len(self.image_paths)}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert("RGB")  # Load image
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Create dataset and DataLoader
train_dataset = ThermalImageDataset("/kaggle/working/split_dataset/train_thermal", transform=transform)

# Check the number of items in the dataset
print(f"Number of images in the dataset: {len(train_dataset)}")

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# Out:
# Processing class: yes
# Processing class: no
# Total images found: 274
# Number of images in the dataset: 274

# %%
# Create model using Swin-B from timm
model = timm.create_model('swin_base_patch4_window7_224', pretrained=True)  # Swin-B model

# Modify the final fully connected layer to match the number of classes
num_classes = len(train_dataset.classes)
model.head = nn.Linear(model.head.in_features, num_classes)  # Modify the classifier head

# Move the model to the appropriate device (GPU if available, otherwise CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]

# %%
# Optimizer and Loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# Mixed Precision Training (if CUDA is available)
scaler = GradScaler()

# Training loop with mixed precision
for epoch in range(100):
    model.train()  # Set model to training mode
    running_loss = 0.0
    correct, total = 0, 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Forward pass using autocast for mixed precision
        with autocast():
            outputs = model(images)
            outputs = outputs.flatten(1)  # Flatten the spatial dimensions for classification

            loss = criterion(outputs, labels)

        # Backpropagation with scaling
        optimizer.zero_grad()  # Clear gradients
        scaler.scale(loss).backward()  # Scale the loss before backpropagation

        # Update the optimizer using scaled loss
        scaler.step(optimizer)  # Update the optimizer
        scaler.update()  # Update the scaler for next iteration

        # Compute metrics
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    # Compute training accuracy
    train_accuracy = 100 * correct / total
    print(f"Epoch [{epoch+1}/100], Loss: {running_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.2f}%")

    # Clear the GPU cache to avoid memory issues
    torch.cuda.empty_cache()

print("Training completed.")
# Out:
# /tmp/ipykernel_36/2197714546.py:6: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipykernel_36/2197714546.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch [1/100], Loss: 3.2736, Accuracy: 18.25%
# Epoch [2/100], Loss: 1.2499, Accuracy: 53.28%
# Epoch [3/100], Loss: 0.9887, Accuracy: 59.49%
# Epoch [4/100], Loss: 0.6659, Accuracy: 68.25%
# Epoch [5/100], Loss: 0.6024, Accuracy: 75.91%
# Epoch [6/100], Loss: 0.4019, Accuracy: 81.75%
# Epoch [7/100], Loss: 0.3505, Accuracy: 83.21%
# Epoch [8/100], Loss: 0.2139, Accuracy: 90.88%
# Epoch [9/100], Loss: 0.2333, Accuracy: 90.15%
# Epoch [10/100], Loss: 0.1909, Accuracy: 94.53%
# Epoch [11/100], Loss: 0.1560, Accuracy: 95.99%
# Epoch [12/100], Loss: 0.1437, Accuracy: 94.53%
# Epoch [13/100], Loss: 0.1118, Accuracy: 97.08%
# Epoch [14/100], Loss: 0.0616, Accuracy: 97.45%
# Epoch [15/100], Loss: 0.1004, Accuracy: 95.62%
# Epoch [16/100], Loss: 0.0783, Accuracy: 97.81%
# Epoch [17/100], Loss: 0.0830, Accuracy: 97.81%
# Epoch [18/100], Loss: 0.0800, Accuracy: 97.08%
# Epoch [19/100], Loss: 0.0528, Accuracy: 98.54%
# Epoch [20/100], Loss: 0.0572, Accuracy: 98.18%
# Epoch [21/100], Loss: 0.0564, Accuracy: 97.45%
# Epoch [22/100], Loss: 0.0682, Accuracy: 98.18%
# Epoch [23/100], Loss: 0.0390, Accuracy: 98.54%
# Epoch [24/100], Loss: 0.0224, Accuracy: 99.27%
# Epoch [25/100], Loss: 0.0100, Accuracy: 99.64%
# Epoch [26/100], Loss: 0.0548, Accuracy: 98.18%
# Epoch [27/100], Loss: 0.0451, Accuracy: 98.91%
# Epoch [28/100], Loss: 0.0382, Accuracy: 98.18%
# Epoch [29/100], Loss: 0.0864, Accuracy: 97.81%
# Epoch [30/100], Loss: 0.0257, Accuracy: 99.27%
# Epoch [31/100], Loss: 0.0235, Accuracy: 99.27%
# Epoch [32/100], Loss: 0.0135, Accuracy: 99.64%
# Epoch [33/100], Loss: 0.0095, Accuracy: 100.00%
# Epoch [34/100], Loss: 0.0190, Accuracy: 98.91%
# Epoch [35/100], Loss: 0.0072, Accuracy: 99.64%
# Epoch [36/100], Loss: 0.0122, Accuracy: 98.91%
# Epoch [37/100], Loss: 0.0155, Accuracy: 99.27%
# Epoch [38/100], Loss: 0.0027, Accuracy: 100.00%
# Epoch [39/100], Loss: 0.0132, Accuracy: 99.27%
# Epoch [40/100], Loss: 0.0178, Accuracy: 99.27%
# Epoch [41/100], Loss: 0.0063, Accuracy: 99.64%
# Epoch [42/100], Loss: 0.0139, Accuracy: 99.64%
# Epoch [43/100], Loss: 0.0022, Accuracy: 100.00%
# Epoch [44/100], Loss: 0.0091, Accuracy: 99.64%
# Epoch [45/100], Loss: 0.0080, Accuracy: 99.64%
# Epoch [46/100], Loss: 0.0075, Accuracy: 99.27%
# Epoch [47/100], Loss: 0.0067, Accuracy: 99.64%
# Epoch [48/100], Loss: 0.0137, Accuracy: 99.27%
# Epoch [49/100], Loss: 0.0021, Accuracy: 100.00%
# Epoch [50/100], Loss: 0.0081, Accuracy: 99.64%
# Epoch [51/100], Loss: 0.0023, Accuracy: 100.00%
# Epoch [52/100], Loss: 0.0092, Accuracy: 99.64%
# Epoch [53/100], Loss: 0.0080, Accuracy: 99.64%
# Epoch [54/100], Loss: 0.0070, Accuracy: 100.00%
# Epoch [55/100], Loss: 0.0041, Accuracy: 99.64%
# Epoch [56/100], Loss: 0.0026, Accuracy: 100.00%
# Epoch [57/100], Loss: 0.0096, Accuracy: 99.64%
# Epoch [58/100], Loss: 0.0115, Accuracy: 99.64%
# Epoch [59/100], Loss: 0.0063, Accuracy: 99.64%
# Epoch [60/100], Loss: 0.0039, Accuracy: 100.00%
# Epoch [61/100], Loss: 0.0059, Accuracy: 99.64%
# Epoch [62/100], Loss: 0.0045, Accuracy: 100.00%
# Epoch [63/100], Loss: 0.0117, Accuracy: 99.27%
# Epoch [64/100], Loss: 0.0066, Accuracy: 100.00%
# Epoch [65/100], Loss: 0.0013, Accuracy: 100.00%
# Epoch [66/100], Loss: 0.0033, Accuracy: 100.00%
# Epoch [67/100], Loss: 0.0052, Accuracy: 99.64%
# Epoch [68/100], Loss: 0.0087, Accuracy: 98.91%
# Epoch [69/100], Loss: 0.0093, Accuracy: 99.27%
# Epoch [70/100], Loss: 0.0009, Accuracy: 100.00%
# Epoch [71/100], Loss: 0.0056, Accuracy: 100.00%
# Epoch [72/100], Loss: 0.0050, Accuracy: 99.64%
# Epoch [73/100], Loss: 0.0008, Accuracy: 100.00%
# Epoch [74/100], Loss: 0.0064, Accuracy: 99.64%
# Epoch [75/100], Loss: 0.0013, Accuracy: 100.00%
# Epoch [76/100], Loss: 0.0143, Accuracy: 99.27%
# Epoch [77/100], Loss: 0.0079, Accuracy: 100.00%
# Epoch [78/100], Loss: 0.0074, Accuracy: 99.64%
# Epoch [79/100], Loss: 0.0075, Accuracy: 99.64%
# Epoch [80/100], Loss: 0.0070, Accuracy: 99.27%
# Epoch [81/100], Loss: 0.0021, Accuracy: 100.00%
# Epoch [82/100], Loss: 0.0019, Accuracy: 100.00%
# Epoch [83/100], Loss: 0.0142, Accuracy: 99.64%
# Epoch [84/100], Loss: 0.0041, Accuracy: 100.00%
# Epoch [85/100], Loss: 0.0084, Accuracy: 99.64%
# Epoch [86/100], Loss: 0.0017, Accuracy: 100.00%
# Epoch [87/100], Loss: 0.0020, Accuracy: 100.00%
# Epoch [88/100], Loss: 0.0008, Accuracy: 100.00%
# Epoch [89/100], Loss: 0.0011, Accuracy: 100.00%
# Epoch [90/100], Loss: 0.0079, Accuracy: 99.64%
# Epoch [91/100], Loss: 0.0010, Accuracy: 100.00%
# Epoch [92/100], Loss: 0.0080, Accuracy: 99.64%
# Epoch [93/100], Loss: 0.0023, Accuracy: 100.00%
# Epoch [94/100], Loss: 0.0280, Accuracy: 98.91%
# Epoch [95/100], Loss: 0.0460, Accuracy: 98.18%
# Epoch [96/100], Loss: 0.0560, Accuracy: 97.81%
# Epoch [97/100], Loss: 0.1103, Accuracy: 97.08%
# Epoch [98/100], Loss: 0.0832, Accuracy: 96.35%
# Epoch [99/100], Loss: 0.1211, Accuracy: 96.35%
# Epoch [100/100], Loss: 0.0771, Accuracy: 98.18%
# Training completed.

# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

class ThermalImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = []
        self.labels = []
        self.classes = ['yes', 'no']  # Assuming only 'yes' and 'no' classes
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}

        # Load image paths and labels
        for label in self.classes:
            class_dir = os.path.join(root_dir, label)
            if os.path.isdir(class_dir):
                for img_folder in os.listdir(class_dir):
                    img_folder_path = os.path.join(class_dir, img_folder)
                    if os.path.isdir(img_folder_path):
                        real_img_path = os.path.join(img_folder_path, f"{img_folder}.jpg")  # Real image
                        thermal_img_path = os.path.join(img_folder_path, f"thermal_{img_folder}.jpg")  # Thermal image

                        # Add the real and thermal image paths with corresponding labels
                        if os.path.exists(real_img_path) and os.path.exists(thermal_img_path):
                            self.image_paths.append((real_img_path, thermal_img_path))
                            self.labels.append(self.class_to_idx[label])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        real_img_path, thermal_img_path = self.image_paths[idx]

        # Load images
        real_image = Image.open(real_img_path).convert("RGB")
        thermal_image = Image.open(thermal_img_path).convert("RGB")

        # Combine real and thermal image (side by side, 6 channels)
        combined_image = Image.new("RGB", (real_image.width * 2, real_image.height))  # Double the width
        combined_image.paste(real_image, (0, 0))
        combined_image.paste(thermal_image, (real_image.width, 0))

        if self.transform:
            combined_image = self.transform(combined_image)

        label = self.labels[idx]
        return combined_image, label


# Define transformations for the validation dataset
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # For ResNet/Swin-B
])

# Define the path to the validation dataset
val_dataset_path = "/kaggle/working/split_dataset/test_thermal"  # Adjust this to the actual path

# Create the validation dataset
val_dataset = ThermalImageDataset(root_dir=val_dataset_path, transform=val_transform)

# Create the DataLoader for the validation dataset
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Check the number of samples in the validation loader
print(f"Number of validation samples: {len(val_loader.dataset)}")
# Out:
# Number of validation samples: 34

# %%
# Validation phase
model.eval()  # Set the model to evaluation mode
correct, total = 0, 0
with torch.no_grad():  # Disable gradient computation
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)

        # Flatten the output for classification (we only need the class scores)
        outputs = outputs.view(outputs.size(0), -1)  # Flatten the spatial dimensions

        # Compute accuracy
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

# Compute and print the validation accuracy
val_accuracy = 100 * correct / total
print(f"Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Validation Accuracy: 79.41%
